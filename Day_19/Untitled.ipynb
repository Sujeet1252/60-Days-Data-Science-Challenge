# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6]
y = [2,4,6,4,7,8]

plt.plot(x,y,color="r",marker="o",label="Matplot")


plt.title("Matplot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.legend()
plt.show()
