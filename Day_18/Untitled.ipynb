# %%
# Out:
# ===== EMPLOYEE ANALYTICS DASHBOARD =====
#    Total_Employees
# 0                7
#    Total_Salary
# 0        425000
#    Average_Salary
# 0    60714.285714
#    Highest_Salary
# 0           80000
#    Lowest_Salary
# 0          45000
