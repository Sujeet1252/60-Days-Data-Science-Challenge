# %%
numbers = [4,5,7,8,6, "mango"]

numbers[2]= "Apple"

numbers.insert(3, 70)

print(numbers)

numbers.append("orange")

print(numbers)

print(numbers[2])

print(numbers[-2])

print(numbers[:3])
# Out:
# [4, 5, 'Apple', 70, 8, 6, 'mango']
# [4, 5, 'Apple', 70, 8, 6, 'mango', 'orange']
# Apple
# mango
# [4, 5, 'Apple']

# %%
list = [12,14,75,53,32,65,34,90,5]
list.sort()
print(list)

list.sort(reverse=True)
print(list)
# Out:
# [5, 12, 14, 32, 34, 53, 65, 75, 90]
# [90, 75, 65, 53, 34, 32, 14, 12, 5]

# %%
name_list = ['Sujeet','Ram','Pratham','Saurabh','mayank']

for i in range(len(name_list)):
    print(name_list[i])

for item in name_list:
    print(item)
# Out:
# Sujeet
# Ram
# Pratham
# Saurabh
# mayank
# Sujeet
# Ram
# Pratham
# Saurabh
# mayank
