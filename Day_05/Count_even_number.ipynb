# %%
numbers = [10, 15, 20, 25, 30, 35, 40]

count = 0

for num in numbers:
    
    if num % 2 == 0:
        
        print(num)
        
        count += 1

print("Even Numbers Count =", count)
# Out:
# 10
# 20
# 30
# 40
# Even Numbers Count = 4
