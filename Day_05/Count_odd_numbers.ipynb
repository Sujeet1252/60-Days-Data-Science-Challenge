# %%
numbers = [10, 15, 20, 25, 30, 35, 40]

count = 0

for num in numbers:
    
    if num % 2 != 0:
        
        print(num)
        
        count += 1

print("Odd Numbers Count =", count)
# Out:
# 15
# 25
# 35
# Odd Numbers Count = 3
