# %% [markdown]
# # Smart Customer Feature Engineering System

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

data={'Customer':['Aman','Rahul','Priya','Neha','Rohit'],'Gender':['Male','Male','Female','Female','Male'],'City':['Delhi','Mumbai','Delhi','Lucknow','Mumbai'],'Age':[22,35,28,41,30],'Salary':[25000,50000,42000,65000,38000],'Purchase':[1500,2200,1800,3500,2700],'Joining_Date':['2022-01-10','2021-06-15','2023-03-20','2020-11-01','2022-09-05']}
df=pd.DataFrame(data)
df['Purchase_Ratio']=df['Purchase']/df['Salary']
df['Salary_per_Age']=df['Salary']/df['Age']
le=LabelEncoder(); df['Gender']=le.fit_transform(df['Gender'])
df=pd.get_dummies(df,columns=['City'])
print(df.head())
# Out:
#   Customer  Gender  Age  Salary  Purchase Joining_Date  Purchase_Ratio  \
# 0     Aman       1   22   25000      1500   2022-01-10        0.060000
# 1    Rahul       1   35   50000      2200   2021-06-15        0.044000
# 2    Priya       0   28   42000      1800   2023-03-20        0.042857
# 3     Neha       0   41   65000      3500   2020-11-01        0.053846
# 4    Rohit       1   30   38000      2700   2022-09-05        0.071053
#
#    Salary_per_Age  City_Delhi  City_Lucknow  City_Mumbai
# 0     1136.363636        True         False        False
# 1     1428.571429       False         False         True
# 2     1500.000000        True         False        False
# 3     1585.365854       False          True        False
# 4     1266.666667       False         False         True
