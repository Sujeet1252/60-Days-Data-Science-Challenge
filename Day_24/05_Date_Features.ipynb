# %% [markdown]
# # Date Features

# %%
import pandas as pd
df=pd.DataFrame({'Date':['2022-01-10','2023-05-20']})
df['Date']=pd.to_datetime(df['Date'])
df['Year']=df['Date'].dt.year
print(df)
# Out:
#         Date  Year
# 0 2022-01-10  2022
# 1 2023-05-20  2023
