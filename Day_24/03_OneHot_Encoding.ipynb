# %% [markdown]
# # One Hot Encoding

# %%
import pandas as pd
df=pd.DataFrame({'City':['Mumbai','Delhi','Lucknow']})
print(pd.get_dummies(df,columns=['City']))
# Out:
#    City_Delhi  City_Lucknow  City_Mumbai
# 0       False         False         True
# 1        True         False        False
# 2       False          True        False
